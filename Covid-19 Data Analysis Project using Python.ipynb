# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\abhis\Downloads\allmetrics_states.csv")

# %%
data.head()
# Out:
#    state        dates  cum_positive_cases  cum_positivity_rate  \
# 0  India   30 January                 1.0                  NaN
# 1  India   31 January                 NaN                  NaN
# 2  India  01 February                 NaN                  NaN
# 3  India  02 February                 2.0                  NaN
# 4  India  03 February                 3.0                  NaN
#
#    daily_positive_cases  cum_recovered  daily_recovered  cum_deceased  \
# 0                   1.0            NaN              NaN           NaN
# 1                   NaN            NaN              NaN           NaN
# 2                   NaN            NaN              NaN           NaN
# 3                   1.0            NaN              NaN           NaN
# 4                   1.0            NaN              NaN           NaN
#
#    daily_deceased  daily_positivity_rate  ...  dbt_point  dbt_l95  dbt_u95  \
# 0             NaN                    NaN  ...        0.0      0.0      0.0
# ...

# %%
data.columns
# Out:
# Index(['state', 'dates', 'cum_positive_cases', 'cum_positivity_rate',
#        'daily_positive_cases', 'cum_recovered', 'daily_recovered',
#        'cum_deceased', 'daily_deceased', 'daily_positivity_rate',
#        'daily_positive_cases_ma', 'daily_positivity_rate_ma', 'daily_tests',
#        'cum_tests', 'test_per_million', 'daily_cases_per_million',
#        'daily_tests_per_million', 'daily_tests_ma', 'daily_deceased_ma',
#        'cfr1_point', 'cfr2_point', 'cfr3_point', 'cfr3_l95', 'cfr3_u95',
#        'cfr3_l50', 'cfr3_u50', 'dbt_point', 'dbt_l95', 'dbt_u95', 'rt_point',
#        'rt_sd', 'rt_l95', 'rt_u95', 'rt_l50', 'rt_u50', 't_end'],
#       dtype='object')

# %%
data.tail()
# Out:
#         state        dates  cum_positive_cases  cum_positivity_rate  \
# 37507  Sikkim  02 December                 NaN                  NaN
# 37508  Sikkim  03 December                 NaN                  NaN
# 37509  Sikkim  04 December                 NaN                  NaN
# 37510  Sikkim  05 December                 NaN                  NaN
# 37511  Sikkim  06 December                 NaN                  NaN
#
#        daily_positive_cases  cum_recovered  daily_recovered  cum_deceased  \
# 37507                   NaN            NaN              NaN           NaN
# 37508                   NaN            NaN              NaN           NaN
# 37509                   NaN            NaN              NaN           NaN
# 37510                   NaN            NaN              NaN           NaN
# 37511                   NaN            NaN              NaN           NaN
#
#        daily_deceased  daily_positivity_rate  ...  dbt_point  dbt_l95  \
# ...

# %%
data.describe()
# Out:
#        cum_positive_cases  cum_positivity_rate  daily_positive_cases  \
# count        1.834700e+04         17663.000000          17083.000000
# mean         6.011752e+05             5.886436           3754.826670
# std          2.515866e+06             3.818449          18703.907179
# min          1.000000e+00             0.011137          -5914.000000
# 25%          4.965500e+03             3.079827             50.000000
# 50%          5.082600e+04             5.177467            279.000000
# 75%          3.284785e+05             7.929024           1606.500000
# max          3.207699e+07            22.203694         414280.000000
#
#        cum_recovered  daily_recovered   cum_deceased  daily_deceased  \
# count   1.774500e+04     16395.000000   16730.000000    12323.000000
# mean    5.755939e+05      3811.838182    8877.774836       69.735697
# std     2.403658e+06     18646.459107   34821.997783      288.688145
# ...

# %%
data.isnull().sum()
# Out:
# state                           0
# dates                           0
# cum_positive_cases          19165
# cum_positivity_rate         19849
# daily_positive_cases        20429
# cum_recovered               19767
# daily_recovered             21117
# cum_deceased                20782
# daily_deceased              25189
# daily_positivity_rate       21586
# daily_positive_cases_ma     19337
# daily_positivity_rate_ma    20484
# daily_tests                 20866
# cum_tests                   19755
# test_per_million            19755
# daily_cases_per_million     20429
# daily_tests_per_million     20866
# daily_tests_ma              20020
# daily_deceased_ma           22484
# cfr1_point                      0
# cfr2_point                      0
# cfr3_point                      0
# cfr3_l95                        0
# cfr3_u95                        0
# cfr3_l50                        0
# cfr3_u50                        0
# dbt_point                     705
# ...

# %%
data.columns
# Out:
# Index(['state', 'dates', 'cum_positive_cases', 'cum_positivity_rate',
#        'daily_positive_cases', 'cum_recovered', 'daily_recovered',
#        'cum_deceased', 'daily_deceased', 'daily_positivity_rate',
#        'daily_positive_cases_ma', 'daily_positivity_rate_ma', 'daily_tests',
#        'cum_tests', 'test_per_million', 'daily_cases_per_million',
#        'daily_tests_per_million', 'daily_tests_ma', 'daily_deceased_ma',
#        'cfr1_point', 'cfr2_point', 'cfr3_point', 'cfr3_l95', 'cfr3_u95',
#        'cfr3_l50', 'cfr3_u50', 'dbt_point', 'dbt_l95', 'dbt_u95', 'rt_point',
#        'rt_sd', 'rt_l95', 'rt_u95', 'rt_l50', 'rt_u50', 't_end'],
#       dtype='object')

# %%
sns.relplot(x="daily_positive_cases",y="daily_recovered", hue='daily_deceased',data=data)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\abhis\Downloads\allmetrics_states.csv")

# %%
data.columns
# Out:
# Index(['state', 'dates', 'cum_positive_cases', 'cum_positivity_rate',
#        'daily_positive_cases', 'cum_recovered', 'daily_recovered',
#        'cum_deceased', 'daily_deceased', 'daily_positivity_rate',
#        'daily_positive_cases_ma', 'daily_positivity_rate_ma', 'daily_tests',
#        'cum_tests', 'test_per_million', 'daily_cases_per_million',
#        'daily_tests_per_million', 'daily_tests_ma', 'daily_deceased_ma',
#        'cfr1_point', 'cfr2_point', 'cfr3_point', 'cfr3_l95', 'cfr3_u95',
#        'cfr3_l50', 'cfr3_u50', 'dbt_point', 'dbt_l95', 'dbt_u95', 'rt_point',
#        'rt_sd', 'rt_l95', 'rt_u95', 'rt_l50', 'rt_u50', 't_end'],
#       dtype='object')

# %%
sns.relplot(x='cum_positive_cases', y='daily_tests_ma',kind='line',data=data)

# %%
data.columns

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data = pd.read_csv(r"C:\Users\abhis\Downloads\allmetrics_states.csv")

# %%
sns.relplot(x='daily_positive_cases', y='daily_tests_ma',kind='line',data=data)
